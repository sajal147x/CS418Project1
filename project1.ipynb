# %%
import pandas as pd

# %%
demographics = pd.read_csv("demographics_data.csv")
election = pd.read_csv("election_data.csv")

# %%
reshaped = election.pivot_table(
    index=["YEAR", "STATE", "COUNTY"],
    columns="PARTY",
    values="VOTES",
    aggfunc="sum"
).reset_index()

# %%
print(f" THE ROW SIZE: {reshaped.shape[0]}")
print(f" NUM COLUMNS: {reshaped.shape[1]}")
# Out:
#  THE ROW SIZE: 3105
#  NUM COLUMNS: 5
